# %% [markdown]
# # Phase 1: Project Setup & Data Acquisition
#
# ## 1.1 Project Repository
#
# Task 1.1: Establish a project repository on GitHub called (ai-arabic-text-detection).
#
# Project Folder Structure:
# - `notebooks/` : يحتوي ملفات Jupyter للتجارب والتحليل.
# - `data/` : مخصص للبيانات الخام أو المعالجة.
# - `reports/` : للتقارير والنتائج.
# - `src/` : للأكواد المنظمة (preprocessing, modeling, visualization).
#
# ---
#
# ## 1.2 Data Acquisition
# Loading data from a Hugging Face:
# `KFUPM-JRCAI/arabic-generated-abstracts`
#
# Split Statistics /المجموعات الفرعية:
# - by_polishing → 2851 صف
# - from_title → 2963 صف
# - from_title_and_content → 2574 صف
# - by_polishing → 2,851 rows
# - from_title → 2,963 rows
# - from_title_and_content → 2,574 rows
#
# Data Fields /الأعمدة المتوفرة في جميع المجموعات:
# - `original_abstract` : النصوص البشرية (Human)
# - `allam_generated_abstract` : النصوص المولدة بواسطة Allam
# - `jais_generated_abstract` : النصوص المولدة بواسطة Jais
# - `llama_generated_abstract` : النصوص المولدة بواسطة LLaMA
# - `openai_generated_abstract` : النصوص المولدة بواسطة OpenAI
#
# ---
#
# ## 1.3 Initial Data Exploration
#
# ### Structure
# - جميع المجموعات تحتوي على نفس الأعمدة المذكورة أعلاه.
# - البيانات منظمة بصيغة نصوص (pandas dtype = object).
# - تمت معاينة العينات (first 5 rows) للتأكد من سلامة البنية.
# -All datasets contain the same columns mentioned above.
# -The data is organized in text format (pandas dtype = object).
# -Samples (first 5 rows) were previewed to verify the integrity of the structure.
# ### Target Distribution (Human vs AI)
# - /إجمالي النصوص البشرية (Original): 8,388
# - إجمالي النصوص المولدة (AI, across 4 models): 33,552
# - يتضح أن كل نص بشري يقابله 4 نصوص مولدة تقريبًا.
# - Total human texts (Original): 8,388
# - Total generated texts (AI, across 4 models): 33,552
# - It is evident that each human text corresponds to approximately 4 generated texts.
# ### Data Quality
# - All columns = 0 (no missing values)/جميع الأعمدة = 0 (لا توجد قيم ناقصة).
# -  Number of duplicate rows = 0 (no duplicates)/عدد الصفوف المكررة = 0 (لا توجد تكرارات).
#
# ---
#
# ## Summary
# - The data has been successfully loaded from the source./البيانات تم تحميلها بنجاح من المصدر.
# - The structure is clear and consistent./البنية واضحة ومتناسقة.
# - The dataset is free from missing and duplicate values./البيانات خالية من القيم المفقودة والمكررة.
# - The distribution shows an abundance of generated samples compared to human ones./التوزيع يظهر وفرة في العينات المولدة مقارنة بالبشرية.
